# %% [markdown]
# ## PYTHON BASICS

# %% [markdown]
# ## WHAT IS PYTHON ?

# %% [markdown]
# - Python is the programming language
# - made by guido van rossum in 1980 but realsed in 1991
# - Beginner-friendly programming language
# - Used in:
# - Data Science
# - AI
# - Web Development
# - Automation

# %% [markdown]
# ## VARIABLES

# %% [markdown]
# - IT IS CONTAINER OR LABEL THAT STORED VALUE WE CAN USE AND MANIPULATE IN OUR PROGRAM

# %%
name = "Pari"
age = 20

# %% [markdown]
# ## DATA TYPES

# %% [markdown]
# 1) String ("Hello")
# 2) Integer (10)
# 3) Float (10.5)
# 4) Boolean (True/False)

# %%
name = "Pari"
marks = 95
percentage = 92.5
is_pass = True

# %%
print(name)
print(marks)
print(percentage)
print(is_pass)
# Out:
# Pari
# 95
# 92.5
# True

# %% [markdown]
# ## Input & Output

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name:  raghav
# raghav

# %% [markdown]
# ## OPERATORS

# %% [markdown]
# # Arithmetic Operators

# %%
+   Addition
-   Subtraction
*   Multiplication
/   Division
%   Modulus
**  Exponent
//  Floor Division

# %%
a = 10
b = 3
c=2
print(a + b)
print(a % b)
print(a//c)
# Out:
# 13
# 1
# 5

# %% [markdown]
# # Comparison Operators

# %%
==   Equal to
!=   Not equal to
>    Greater than
<    Less than
>=   Greater than equal to
<=   Less than equal to

# %% [markdown]
# # Assignment Operators

# %%
= 
+=
-=
*=
/=
%=

# %%
x = 5
x += 2
print(x)
# Out:
# 7

# %% [markdown]
# # Logical Operators

# %%
and
or
not

# %% [markdown]
# # Identity Operators

# %%
is
is not

# %% [markdown]
# # Membership Operators

# %%
in
not in

# %%
name = "Pari"

print("P" in name)
# Out:
# True

# %% [markdown]
# ## Bitwise Operators

# %%
&
|
^
~
<<
>>

# %% [markdown]
# # Total Main Types of Operators = 7

# %% [markdown]
# # EXAMPLES FOR BASIC

# %% [markdown]
# # program - 01

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name:  sanu
# Hello sanu

# %% [markdown]
# # program - 02

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
# Out:
# Enter first number:  12
# Enter second number:  2
# Addition: 14
# Subtraction: 10

# %% [markdown]
# # rectangle area

# %%
length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

area = length * breadth

print("Area =", area)
# Out:
# Enter length:  20
# Enter breadth:  10
# Area = 200.0
